# %% [markdown]
# <a href="https://colab.research.google.com/github/ajmorenob/Modelado-y-Simulacion/blob/master/Ecuaci%C3%B3n_de_Lorenz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ecuación de Lorenz**
#
# El modelo de Lorenz se deduce de las ecuaciones de Navier-Stokes para el movimiento de un fluido. Estas ecuaciones relacionan las diferentes propiedades de un fluido, como la velocidad, la densidad, la presión, etc., entre sí, y son ecuaciones no lineales

# %% [markdown]
# Módulos de librerias

# %%
import matplotlib.style
matplotlib.style.use('classic')
import numpy as np
import time
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp
from mpl_toolkits.mplot3d import axes3d

# %%
def Lorenz_eq(t,xyz,sigma,beta,rho):
    x,y,z = xyz
    return [sigma*(y-x),x*(rho-z)-y,x*y-beta*z]

# %%
time = [0,100]
t = np.arange(time[0],time[1],0.001)
init_condi = [1,1,0]
solucion = solve_ivp(Lorenz_eq,time,init_condi,args=[10,8/3,28],t_eval=t)
t = solucion.t
x = solucion.y[0,:]
y = solucion.y[1,:]
z = solucion.y[2,:]

fig = plt.figure(figsize=(20,10))
ax = fig.gca(projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
plt.figure(figsize=(20,10))

plt.subplot(3,1,1)
plt.plot(t,x)
plt.ylabel('x')
plt.xlabel('t')

plt.subplot(3,1,2)
plt.plot(t,y)
plt.ylabel('y')
plt.xlabel('t')

plt.subplot(3,1,3)
plt.plot(t,z)
plt.ylabel('z')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# #Diagrama de Bifurcaciones
# En matemáticas, un diagrama de bifurcación de un sistema dinámico es una estratificación de su espacio de parámetros inducida por la equivalencia topológica, junto con los retratos de fase representativos de cada estrato. Las soluciones estables suelen representarse mediante líneas continuas, mientras que las soluciones inestables se representan con líneas punteadas

# %%
def event_lorenz(t,xyz,sigma,beta,rho):
    x,y,z = xyz
    return x+y

# %%
event_lorenz.direction = -1
time = [0,50]
t = np.linspace(time[0],time[1],10000)
init_condi = [0.1,0.1,0.1]

# %%
rs = np.arange(200,235,0.1)
for r in rs:
    solucion = solve_ivp(Lorenz_eq,time,init_condi,events=[event_lorenz],args=[10,8/3,r],t_eval=t)
    for i,t_ in enumerate(solucion.t_events[0]):
        if t_ > 20:
            plt.plot(r,solucion.y_events[0][i,1],'.k')
    init_condi = solucion.y[:,-1]
